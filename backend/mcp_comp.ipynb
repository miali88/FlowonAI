# %%
from composio_openai import ComposioToolSet, App
from openai import OpenAI
from dotenv import load_dotenv
import os 
load_dotenv()

openai_client = OpenAI()
composio_toolset = ComposioToolSet(entity_id="default")

tools = composio_toolset.get_tools(apps=[App.SLACK])
# Out:
# [2025-03-22 16:28:08,130][INFO] Logging is set to INFO, use `logging_level` argument or `COMPOSIO_LOGGING_LEVEL` change this
# /Users/michaelali/Repos/flowon_ai/venv/lib/python3.12/site-packages/composio/client/collections.py:1151: UserWarning: Using all actions of an app is not recommended for production.Learn more: https://docs.composio.dev/patterns/tools/use-tools/use-specific-actions
#   warnings.warn(

# %%
vars(tools[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 vars(tools[0])
#
# TypeError: vars() argument must have __dict__ attribute

# %%
tools
# Out:
# [{'type': 'function',
#   'function': {'name': 'SLACK_ADD_REACTION_TO_AN_ITEM',
#    'description': "Adds a reaction (emoji) to a specific message in a slack channel. this endpoint allows users to interact with messages by adding emojis as reactions, enhancing engagement and communication within slack. it should be used when a user wants to express a quick response or sentiment to a message without sending a new message. the endpoint requires specifying the target channel, the emoji name, and the timestamp of the message to react to. it's important to note that the user must have access to the specified channel and message, and the emoji must be available in the slack workspace. this endpoint does not support removing reactions or retrieving existing reactions on a message.",
#    'parameters': {'properties': {'channel': {'description': 'Channel where the message to add reaction to was posted. Please provide a value of type string. This parameter is required.',
#       'title': 'Channel',
#       'type': 'string'},
#      'name': {'description': 'Reaction (emoji) name. Please provide a value of type string. This parameter is required.',
#       'title': 'Name',
#       'type': 'string'},
#      'timestamp': {'description': 'Timestamp of the message to add reaction to. Please provide a value of type string. This parameter is required.',
#       'title': 'Timestamp',
#       'type': 'string'}},
#     'title': 'AddReactionToAnItemRequest',
#     'type': 'object',
#     'required': ['channel', 'name', 'timestamp']}}},
#  {'type': 'function',
#   'function': {'name': 'SLACK_SCHEDULES_A_MESSAGE_TO_A_CHANNEL_AT_A_SPECIFIED_TIME',
#    'description': 'The chat.schedulemessage endpoint allows you to schedule a message for future delivery in a slack channel, direct message, or private group. this powerful feature enables automated, time-based communication within your slack workspace. use this endpoint when you need to send messages at specific times, such as reminders, announcements, or recurring updates. the scheduled message can include rich formatting using attachments or blocks, and supports various customization options like threading and link unfurling. keep in mind that scheduled messages are typically limited to 120 days in the future, and the scheduling user must have the necessary permissions in the target channel.',
#    'parameters': {'properties': {'as_user': {'default': None,
#       'description': 'Pass true to post the message as the authed user, instead of as a bot. Defaults to false. See [chat.postMessage](chat.postMessage#authorship). . Please provide a value of type boolean.',
#       'title': 'As User',
#       'type': 'boolean'},
#      'attachments': {'default': None,
#       'description': 'A JSON-based array of structured attachments, presented as a URL-encoded string. . Please provide a value of type string.',
#       'title': 'Attachments',
#       'type': 'string'},
#      'blocks': {'default': None,
#       'description': 'A JSON-based array of structured blocks, presented as a URL-encoded string. . Please provide a value of type string.',
#       'title': 'Blocks',
#       'type': 'string'},
#      'channel': {'default': None,
#       'description': 'Channel, private group, or DM channel to send message to. Can be an encoded ID, or a name. See [below](https://slack.dev) for more details. . Please provide a value of type string.',
#       'title': 'Channel',
#       'type': 'string'},
#      'link_names': {'default': None,
#       'description': 'Find and link channel names and usernames. Please provide a value of type boolean.',
#       'title': 'Link Names',
#       'type': 'boolean'},
#      'parse': {'default': None,
#       'description': 'Change how messages are treated. Defaults to `none`. See [chat.postMessage](chat.postMessage#formatting). . Please provide a value of type string.',
#       'title': 'Parse',
#       'type': 'string'},
#      'post_at': {'default': None,
#       'description': 'Unix EPOCH timestamp of time in future to send the message. Please provide a value of type string.',
#       'title': 'Post At',
#       'type': 'string'},
#      'reply_broadcast': {'default': None,
#       'description': 'Used in conjunction with `thread_ts` and indicates whether reply should be made visible to everyone in the channel or conversation. Defaults to `false`. . Please provide a value of type boolean.',
#       'title': 'Reply Broadcast',
#       'type': 'boolean'},
#      'text': {'default': None,
#       'description': 'How this field works and whether it is required depends on other fields you use in your API call. [See below](https://slack.dev) for more detail. . Please provide a value of type string.',
#       'title': 'Text',
#       'type': 'string'},
#      'thread_ts': {'default': None,
#       'description': 'Provide another message"s `ts` value to make this message a reply. Avoid using a reply"s `ts` value; use its parent instead. . Please provide a value of type integer.',
#       'title': 'Thread Ts',
#       'type': 'integer'},
#      'unfurl_links': {'default': None,
#       'description': 'Pass true to enable unfurling of primarily text-based content. Please provide a value of type boolean.',
#       'title': 'Unfurl Links',
#       'type': 'boolean'},
#      'unfurl_media': {'default': None,
#       'description': 'Pass false to disable unfurling of media content. Please provide a value of type boolean.',
#       'title': 'Unfurl Media',
#       'type': 'boolean'}},
#     'title': 'SchedulesAMessageToAChannelAtASpecifiedTimeRequest',
#     'type': 'object'}}},
#  {'type': 'function',
#   'function': {'name': 'SLACK_FETCH_CONVERSATION_HISTORY',
#    'description': "Retrieves the message history of a specified slack conversation or channel. this endpoint allows you to fetch a chronological list of messages and events that have occurred within a channel, group, or direct message conversation. it's particularly useful for applications that need to analyze conversation patterns, create chat archives, or display message history to users. the endpoint supports pagination for handling large message histories and allows filtering by time range. it returns detailed message objects including sender information, timestamps, and message content, making it a powerful tool for building slack integrations that require access to conversation data.",
#    'parameters': {'properties': {'channel': {'default': None,
#       'description': 'Conversation ID to fetch history for. Please provide a value of type string.',
#       'title': 'Channel',
#       'type': 'string'},
#      'latest': {'default': None,
#       'description': 'End of time range of messages to include in results. Please provide a value of type integer.',
#       'title': 'Latest',
#       'type': 'integer'},
#      'oldest': {'default': None,
#       'description': 'Start of time range of messages to include in results. Please provide a value of type integer.',
#       'title': 'Oldest',
#       'type': 'integer'},
#      'inclusive': {'default': None,
#       'description': 'Include messages with latest or oldest timestamp in results only when either timestamp is specified. . Please provide a value of type boolean.',
#       'title': 'Inclusive',
#       'type': 'boolean'},
#      'limit': {'default': None,
#       'description': 'The maximum number of items to return. Fewer than the requested number of items may be returned, even if the end of the users list hasn"t been reached. . Please provide a value of type integer.',
#       'title': 'Limit',
#       'type': 'integer'},
#      'cursor': {'default': None,
#       'description': 'Paginate through collections of data by setting the `cursor` parameter to a `next_cursor` attribute returned by a previous request"s `response_metadata`. Default value fetches the first "page" of the collection. See [pagination](https://slack.dev) for more detail. . Please provide a value of type string.',
#       'title': 'Cursor',
#       'type': 'string'}},
#     'title': 'FetchConversationHistoryRequest',
#     'type': 'object'}}},
#  {'type': 'function',
#   'function': {'name': 'SLACK_REMOVE_REACTION_FROM_ITEM',
#    'description': 'The reactions.remove endpoint allows you to remove a specific reaction (emoji) from a message, file, or file comment in slack. this method is useful for undoing reactions or cleaning up emoji responses on various items within slack channels. to use this endpoint, you must specify the reaction name and the item (message, file, or file comment) from which to remove the reaction. for messages, both the channel and timestamp are required. for files or file comments, you need to provide the respective file or file comment id. this endpoint is particularly helpful for moderation purposes or when managing automated reactions in integrated applications.',
#    'parameters': {'properties': {'channel': {'default': None,
#       'description': 'Channel where the message to remove reaction from was posted. Please provide a value of type string.',
#       'title': 'Channel',
#       'type': 'string'},
#      'file': {'default': None,
#       'description': 'File to remove reaction from. Please provide a value of type string.',
#       'title': 'File',
#       'type': 'string'},
#      'file_comment': {'default': None,
#       'description': 'File comment to remove reaction from. Please provide a value of type string.',
#       'title': 'File Comment',
#       'type': 'string'},
#      'name': {'description': 'Reaction (emoji) name. Please provide a value of type string. This parameter is required.',
#       'title': 'Name',
#       'type': 'string'},
#      'timestamp': {'default': None,
#       'description': 'Timestamp of the message to remove reaction from. Please provide a value of type string.',
#       'title': 'Timestamp',
#       'type': 'string'}},
#     'title': 'RemoveReactionFromItemRequest',
#     'type': 'object',
#     'required': ['name']}}},
#  {'type': 'function',
#   'function': {'name': 'SLACK_LIST_ALL_SLACK_TEAM_CHANNELS_WITH_VARIOUS_FILTERS',
#    'description': "Retrieves a list of all conversations in a slack workspace, including public channels, private channels, multi-person direct messages (mpim), and direct messages (im). this endpoint is essential for obtaining an overview of all available conversations, which can be used for workspace analysis, channel management, or as a precursor to performing actions on specific conversations. the method supports filtering by conversation types, exclusion of archived channels, and pagination for handling large workspaces efficiently. use this endpoint when you need to display available channels to users, perform workspace-wide operations, or gather data about the structure of a slack workspace. note that the returned list may be affected by the permissions of the authenticated user, and some conversations might be excluded if the user doesn't have access to them.",
#    'parameters': {'properties': {'exclude_archived': {'default': None,
#       'description': 'Set to `true` to exclude archived channels from the list. Please provide a value of type boolean.',
#       'title': 'Exclude Archived',
#       'type': 'boolean'},
#      'types': {'default': None,
#       'description': 'Mix and match channel types by providing a comma-separated list of any combination of `public_channel`, `private_channel`, `mpim`, `im` . Please provide a value of type string.',
#       'title': 'Types',
#       'type': 'string'},
#      'limit': {'default': 1,
#       'description': 'The maximum number of items to return. Fewer than the requested number of items may be returned, even if the end of the list hasn"t been reached. Must be an integer no larger than 1000. . Please provide a value of type integer.',
#       'title': 'Limit',
#       'type': 'integer'},
#      'cursor': {'default': None,
#       'description': 'Paginate through collections of data by setting the `cursor` parameter to a `next_cursor` attribute returned by a previous request"s `response_metadata`. Default value fetches the first "page" of the collection. See [pagination](https://slack.dev) for more detail. . Please provide a value of type string.',
#       'title': 'Cursor',
#       'type': 'string'}},
#     'title': 'ListAllSlackTeamChannelsWithVariousFiltersRequest',
#     'type': 'object'}}},
#  {'type': 'function',
#   'function': {'name': 'SLACK_UPDATES_A_SLACK_MESSAGE',
#    'description': "The chat.update endpoint allows you to modify an existing message in a slack channel. it's used when you need to update the content, attachments, or formatting of a previously sent message. this can be particularly useful for updating dynamic content, correcting errors, or providing real-time updates to information. the endpoint requires specifying both the channel and the timestamp of the message to be updated. it offers flexible options for updating the message text, attachments, and blocks, allowing for rich formatting and interactive elements. however, it's important to note that this endpoint can't be used to update messages sent by other users or apps, and there may be time limitations on how long after a message is sent that it can be updated.",
#    'parameters': {'properties': {'as_user': {'default': None,
#       'description': 'Pass true to update the message as the authed user. [Bot users](https://slack.dev) in this context are considered authed users. . Please provide a value of type string.',
#       'title': 'As User',
#       'type': 'string'},
#      'attachments': {'default': None,
#       'description': 'A JSON-based array of structured attachments, presented as a URL-encoded string. This field is required when not presenting `text`. If you don"t include this field, the message"s previous `attachments` will be retained. To remove previous `attachments`, include an empty array for this field. . Please provide a value of type string.',
#       'title': 'Attachments',
#       'type': 'string'},
#      'blocks': {'default': None,
#       'description': 'A JSON-based array of [structured blocks](https://slack.dev), presented as a URL-encoded string. If you don"t include this field, the message"s previous `blocks` will be retained. To remove previous `blocks`, include an empty array for this field. . Please provide a value of type string.',
#       'title': 'Blocks',
#       'type': 'string'},
#      'channel': {'description': 'Channel containing the message to be updated. Please provide a value of type string. This parameter is required.',
#       'title': 'Channel',
#       'type': 'string'},
#      'link_names': {'default': None,
#       'description': 'Find and link channel names and usernames. Defaults to `none`. If you do not specify a value for this field, the original value set for the message will be overwritten with the default, `none`. . Please provide a value of type string.',
#       'title': 'Link Names',
#       'type': 'string'},
#      'parse': {'default': None,
#       'description': 'Change how messages are treated. Defaults to `client`, unlike `chat.postMessage`. Accepts either `none` or `full`. If you do not specify a value for this field, the original value set for the message will be overwritten with the default, `client`. . Please provide a value of type string.',
#       'title': 'Parse',
#       'type': 'string'},
#      'text': {'default': None,
#       'description': 'New text for the message, using the [default formatting rules](https://slack.dev). It"s not required when presenting `blocks` or `attachments`. . Please provide a value of type string.',
#       'title': 'Text',
#       'type': 'string'},
#      'ts': {'description': 'Timestamp of the message to be updated. Please provide a value of type string. This parameter is required.',
#       'title': 'Ts',
#       'type': 'string'}},
#     'title': 'UpdatesASlackMessageRequest',
#     'type': 'object',
#     'required': ['channel', 'ts']}}},
#  {'type': 'function',
#   'function': {'name': 'SLACK_CREATE_A_REMINDER',
#    'description': "The 'reminders.add' endpoint allows you to create new reminders in slack. it's designed to help users set notifications for future tasks, events, or any information they need to remember. this tool is particularly useful for managing personal tasks, setting team reminders, or scheduling follow-ups within slack's collaborative environment. the endpoint offers flexibility in timing, supporting one-time reminders as well as recurring ones through natural language input. while it focuses on creating reminders, it does not provide functionality for listing, modifying, or deleting existing reminders. note that if no specific user is designated, the reminder defaults to the creator, making it versatile for both personal and team use.",
#    'parameters': {'properties': {'text': {'description': 'The content of the reminder. Please provide a value of type string. This parameter is required.',
#       'title': 'Text',
#       'type': 'string'},
#      'time': {'description': 'When this reminder should happen: the Unix timestamp (up to five years from now), the number of seconds until the reminder (if within 24 hours), or a natural language description (Ex. "in 15 minutes," or "every Thursday") . Please provide a value of type string. This parameter is required.',
#       'title': 'Time',
#       'type': 'string'},
#      'user': {'default': None,
#       'description': 'The user who will receive the reminder. If no user is specified, the reminder will go to user who created it. . Please provide a value of type string.',
#       'title': 'User',
#       'type': 'string'}},
#     'title': 'CreateAReminderRequest',
#     'type': 'object',
#     'required': ['text', 'time']}}},
#  {'type': 'function',
#   'function': {'name': 'SLACK_SEARCH_FOR_MESSAGES_WITH_QUERY',
#    'description': 'The search.messages endpoint allows you to search for messages across all channels, direct messages, and private groups in a slack workspace. it provides powerful search capabilities to find specific content within conversations. this endpoint is particularly useful for retrieving historical information, locating important discussions, or building search functionality into slack-integrated applications. the search results include message content, associated metadata, and can be refined using various parameters for sorting, highlighting, and pagination. keep in mind that the search may not include very recent messages due to indexing delays, and there may be rate limits on the number of requests you can make in a given time period.',
#    'parameters': {'properties': {'count': {'default': 1,
#       'description': 'Pass the number of results you want per "page". Maximum of `100`. Please provide a value of type integer.',
#       'title': 'Count',
#       'type': 'integer'},
#      'highlight': {'default': None,
#       'description': 'Pass a value of `true` to enable query highlight markers (see below). Please provide a value of type boolean.',
#       'title': 'Highlight',
#       'type': 'boolean'},
#      'page': {'default': None,
#       'description': 'Page. Please provide a value of type integer.',
#       'title': 'Page',
#       'type': 'integer'},
#      'query': {'description': 'Search query. Please provide a value of type string. This parameter is required.',
#       'title': 'Query',
#       'type': 'string'},
#      'sort': {'default': None,
#       'description': 'Return matches sorted by either `score` or `timestamp`. Please provide a value of type string.',
#       'title': 'Sort',
#       'type': 'string'},
#      'sort_dir': {'default': None,
#       'description': 'Change sort direction to ascending (`asc`) or descending (`desc`). Please provide a value of type string.',
#       'title': 'Sort Dir',
#       'type': 'string'}},
#     'title': 'SearchForMessagesWithQueryRequest',
#     'type': 'object',
#     'required': ['query']}}},
#  {'type': 'function',
#   'function': {'name': 'SLACK_SENDS_A_MESSAGE_TO_A_SLACK_CHANNEL',
#    'description': "The chat.postmessage endpoint allows you to send a message to a slack channel or user. this versatile tool can be used to post simple text messages, create rich interactive messages with blocks or attachments, initiate or reply to threads, and customize the appearance of bot messages. it's ideal for sending notifications, updates, or interactive content to slack users or channels programmatically. the endpoint supports extensive customization of message content and appearance, making it suitable for a wide range of use cases from simple notifications to complex interactive workflows. however, it's important to note that the message structure and appearance may vary depending on the slack client and the parameters used.",
#    'parameters': {'properties': {'as_user': {'default': None,
#       'description': 'Pass true to post the message as the authed user, instead of as a bot. Defaults to false. See [authorship](https://slack.dev) below. . Please provide a value of type boolean.',
#       'title': 'As User',
#       'type': 'boolean'},
#      'attachments': {'default': None,
#       'description': 'A JSON-based array of structured attachments, presented as a URL-encoded string. . Please provide a value of type string.',
#       'title': 'Attachments',
#       'type': 'string'},
#      'blocks': {'default': None,
#       'description': 'A JSON-based array of structured blocks, presented as a URL-encoded string. . Please provide a value of type string.',
#       'title': 'Blocks',
#       'type': 'string'},
#      'channel': {'description': 'Channel, private group, or IM channel to send message to. Can be an encoded ID, or a name. See [below](https://slack.dev) for more details. . Please provide a value of type string. This parameter is required.',
#       'title': 'Channel',
#       'type': 'string'},
#      'icon_emoji': {'default': None,
#       'description': 'Emoji to use as the icon for this message. Overrides `icon_url`. Must be used in conjunction with `as_user` set to `false`, otherwise ignored. See [authorship](https://slack.dev) below. . Please provide a value of type string.',
#       'title': 'Icon Emoji',
#       'type': 'string'},
#      'icon_url': {'default': None,
#       'description': 'URL to an image to use as the icon for this message. Must be used in conjunction with `as_user` set to false, otherwise ignored. See [authorship](https://slack.dev) below. . Please provide a value of type string.',
#       'title': 'Icon Url',
#       'type': 'string'},
#      'link_names': {'default': None,
#       'description': 'Find and link channel names and usernames. Please provide a value of type boolean.',
#       'title': 'Link Names',
#       'type': 'boolean'},
#      'mrkdwn': {'default': None,
#       'description': 'Disable Slack markup parsing by setting to `false`. Enabled by default. Please provide a value of type boolean.',
#       'title': 'Mrkdwn',
#       'type': 'boolean'},
#      'parse': {'default': None,
#       'description': 'Change how messages are treated. Defaults to `none`. See [below](https://slack.dev). . Please provide a value of type string.',
#       'title': 'Parse',
#       'type': 'string'},
#      'reply_broadcast': {'default': None,
#       'description': 'Used in conjunction with `thread_ts` and indicates whether reply should be made visible to everyone in the channel or conversation. Defaults to `false`. . Please provide a value of type boolean.',
#       'title': 'Reply Broadcast',
#       'type': 'boolean'},
#      'text': {'default': None,
#       'description': 'How this field works and whether it is required depends on other fields you use in your API call. [See below](https://slack.dev) for more detail. . Please provide a value of type string.',
#       'title': 'Text',
#       'type': 'string'},
#      'thread_ts': {'default': None,
#       'description': 'Provide another message"s `ts` value to make this message a reply. Avoid using a reply"s `ts` value; use its parent instead. . Please provide a value of type string.',
#       'title': 'Thread Ts',
#       'type': 'string'},
#      'unfurl_links': {'default': None,
#       'description': 'Pass true to enable unfurling of primarily text-based content. Please provide a value of type boolean.',
#       'title': 'Unfurl Links',
#       'type': 'boolean'},
#      'unfurl_media': {'default': None,
#       'description': 'Pass false to disable unfurling of media content. Please provide a value of type boolean.',
#       'title': 'Unfurl Media',
#       'type': 'boolean'},
#      'username': {'default': None,
#       'description': 'Set your bot"s user name. Must be used in conjunction with `as_user` set to false, otherwise ignored. See [authorship](https://slack.dev) below. . Please provide a value of type string.',
#       'title': 'Username',
#       'type': 'string'}},
#     'title': 'SendsAMessageToASlackChannelRequest',
#     'type': 'object',
#     'required': ['channel']}}},
#  {'type': 'function',
#   'function': {'name': 'SLACK_LIST_ALL_SLACK_TEAM_USERS_WITH_PAGINATION',
#    'description': "The 'users.list' endpoint retrieves a comprehensive list of users within a slack workspace. it provides detailed information about each user, including their profile data, account settings, and team memberships. this endpoint is particularly useful for applications that need to synchronize user data, manage user permissions, or perform bulk operations on user accounts. the response includes both active and deactivated users, allowing for a complete overview of the workspace's user base. however, it's important to note that the endpoint may not return real-time data, and there might be a slight delay in reflecting recent changes to user accounts.",
#    'parameters': {'properties': {'limit': {'default': 1,
#       'description': 'The maximum number of items to return. Fewer than the requested number of items may be returned, even if the end of the users list hasn"t been reached. Providing no `limit` value will result in Slack attempting to deliver you the entire result set. If the collection is too large you may experience `limit_required` or HTTP 500 errors. . Please provide a value of type integer.',
#       'title': 'Limit',
#       'type': 'integer'},
#      'cursor': {'default': None,
#       'description': 'Paginate through collections of data by setting the `cursor` parameter to a `next_cursor` attribute returned by a previous request"s `response_metadata`. Default value fetches the first "page" of the collection. See [pagination](https://slack.dev) for more detail. . Please provide a value of type string.',
#       'title': 'Cursor',
#       'type': 'string'},
#      'include_locale': {'default': None,
#       'description': 'Set this to `true` to receive the locale for users. Defaults to `false`. Please provide a value of type boolean.',
#       'title': 'Include Locale',
#       'type': 'boolean'}},
#     'title': 'ListAllSlackTeamUsersWithPaginationRequest',
#     'type': 'object'}}}]
