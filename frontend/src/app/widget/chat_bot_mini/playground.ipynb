# %%
import os
from openai import OpenAI
from supabase import create_client, Client
from dotenv import load_dotenv

load_dotenv()

# Initialize OpenAI client
openai_client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

# Initialize Supabase client
url: str = os.getenv("SUPABASE_URL")
key: str = os.getenv("SUPABASE_SERVICE_ROLE_KEY")
supabase: Client = create_client(url, key)

def get_embedding(text: str) -> list:
    openai_client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))
    print(" func get_embedding..")
    response = openai_client.embeddings.create(
        input=text,
        model="text-embedding-3-small"
    )
    return response.data[0].embedding


def insert_into_supabase(content: str, embedding: list):
    print(" func insert_into_supabase..")
    data = supabase.table("knowledge_base").insert({"content": content, "embedding": embedding}).execute()
    return data

# Example usage
content = "This is an example piece of content for our knowledge base."
embedding = get_embedding(content)
result = insert_into_supabase(content, embedding)
print(result)
# Out:
#  func get_embedding..
#  func insert_into_supabase..
# ...

# %%
new_item = supabase.table('knowledge_base').insert("meep").execute()

# %%
new_item
# Out:
# APIResponse[TypeVar](data=[], count=None)

# %%
supabase.table("knowledge_base")
